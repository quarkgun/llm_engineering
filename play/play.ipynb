# %%
#from google.oauth2.credentials import Credentials
#from google_auth_oauthlib.flow import InstalledAppFlow
# from googleapiclient.discovery import build
from bs4 import BeautifulSoup
import requests
from IPython.display import Markdown, display

# %%
def display_text(text):
    display(text)

# %%
HEADERS = {"Content-Type": "application/json"}
url = "https://docs.google.com/document/d/e/2PACX-1vTMOmshQe8YvaRXi6gEPKKlsC6UpFJSMAk4mQjLm_u1gmHdVVTaeh7nBNFBRlui0sTZ-snGwZM4DBCT/pub"
response = requests.get(url, headers=HEADERS)

# %%
html = response.text
i1 = html.find("<table")
i2 = html.find("</table>")

print(i1)
print(i2)
# Out:
# 9217
# 11783

# %%
table = html[i1:i2]
table
# Out:
# '<table class="c9"><tr class="c4"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">x-coordinate</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">Character</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">y-coordinate</span></p></td></tr><tr class="c4"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">0</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">█</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">0</span></p></td></tr><tr class="c4"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">0</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">█</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">1</span></p></td></tr><tr class="c4"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">0</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">█</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">2</span></p></td></tr><tr class="c4"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">1</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">▀</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">1</span></p></td></tr><tr class="c4"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">1</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">▀</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">2</span></p></td></tr><tr class="c4"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">2</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">▀</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">1</span></p></td></tr><tr class="c4"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">2</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">▀</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">2</span></p></td></tr><tr class="c5"><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">3</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span class="c0">▀</span></p></td><td class="c2" colspan="1" rowspan="1"><p class="c1"><span>2</span></p></td></tr>'

# %%
soup = BeautifulSoup(table, 'html.parser')

# %%
soup.
